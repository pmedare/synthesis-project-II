# %% [markdown]
# ---
#
# # Load the data

# %%
import pandas as pd
import numpy as np

# %%
classesDF  = pd.read_csv('../../../data/elliptic_txs_classes.csv')

# Remove all nodes that have unknown class
classesDF = classesDF[classesDF['class'] != "unknown"]

# If class = 2, then map to 0, else map to 1
classesDF['class'] = classesDF['class'].map({'2': 0, '1': 1})

classesDF.head(5)
# Out:
#          txId  class
# 3   232438397      0
# 9   232029206      0
# 10  232344069      0
# 11   27553029      0
# 16    3881097      0

# %%
featuresDF = pd.read_csv('../../../data/elliptic_txs_features.csv')

# Change column names --> Column 1 is txId, Column 2 is timestep and the rest are unknown features
featuresDF.columns = ['txId', 'timestep'] + ['f' + str(i) for i in range(165)]

# Remove all edges that do not appear in classesDF
featuresDF = featuresDF[featuresDF['txId'].isin(classesDF['txId'])]

featuresDF.head(5)
# Out:
#          txId  timestep        f0        f1        f2         f3        f4  \
# 2   232438397         1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 8   232029206         1 -0.005027  0.578941 -0.091383   4.380281 -0.063725
# 9   232344069         1 -0.147852 -0.184668 -1.201369  -0.121970 -0.043875
# 10   27553029         1 -0.151357 -0.184668 -1.201369  -0.121970 -0.043875
# 15    3881097         1 -0.172306 -0.184668 -1.201369   0.028105 -0.043875
#
#           f5         f6        f7  ...      f155      f156      f157  \
# 2   9.782742  12.414558 -0.163645  ... -0.577099 -0.613614  0.241128
# 8   4.667146   0.851305 -0.163645  ... -0.577099 -0.613614  0.241128
# 9  -0.113002  -0.061584 -0.137933  ... -0.577099 -0.613614  0.241128
# 10 -0.113002  -0.061584 -0.141519  ... -0.539735 -0.582077 -0.979074
# 15 -0.029140   0.242712 -0.163640  ... -0.577099 -0.600999  0.241128
#
#         f158      f159      f160      f161      f162      f163      f164
# 2   0.241406  1.072793  0.085530 -0.131155  0.677799 -0.120613 -0.119792
# 8   0.241406  0.604120  0.008632 -0.131155  0.333211 -0.120613 -0.119792
# 9   0.241406  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 10 -0.978556  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 15  0.241406  0.018279 -0.068266 -0.084674 -0.054450 -1.760926 -1.760984
#
# [5 rows x 167 columns]

# %%
# Append the class to the featuresDF based on txID
featuresDF = featuresDF.merge(classesDF, on='txId')

# Move features 'class' to first column
cols = list(featuresDF.columns)
cols = cols[:1] + [cols[-1]] + cols[1:-1]
featuresDF = featuresDF[cols]

featuresDF.head(5)
# Out:
#         txId  class  timestep        f0        f1        f2         f3  \
# 0  232438397      0         1  0.163054  1.963790 -0.646376  12.409294
# 1  232029206      0         1 -0.005027  0.578941 -0.091383   4.380281
# 2  232344069      0         1 -0.147852 -0.184668 -1.201369  -0.121970
# 3   27553029      0         1 -0.151357 -0.184668 -1.201369  -0.121970
# 4    3881097      0         1 -0.172306 -0.184668 -1.201369   0.028105
#
#          f4        f5         f6  ...      f155      f156      f157      f158  \
# 0 -0.063725  9.782742  12.414558  ... -0.577099 -0.613614  0.241128  0.241406
# 1 -0.063725  4.667146   0.851305  ... -0.577099 -0.613614  0.241128  0.241406
# 2 -0.043875 -0.113002  -0.061584  ... -0.577099 -0.613614  0.241128  0.241406
# 3 -0.043875 -0.113002  -0.061584  ... -0.539735 -0.582077 -0.979074 -0.978556
# 4 -0.043875 -0.029140   0.242712  ... -0.577099 -0.600999  0.241128  0.241406
#
#        f159      f160      f161      f162      f163      f164
# 0  1.072793  0.085530 -0.131155  0.677799 -0.120613 -0.119792
# 1  0.604120  0.008632 -0.131155  0.333211 -0.120613 -0.119792
# 2  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 3  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 4  0.018279 -0.068266 -0.084674 -0.054450 -1.760926 -1.760984
#
# [5 rows x 168 columns]

# %% [markdown]
# ### Compute PCA to reduce the dimensionality of the features

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Compute PCA on the features
pca = PCA()
pca.fit(featuresDF.iloc[:, 2:]) # Ignore the first column (txId)

# Calculate cumulative explained variance ratio
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Set a threshold of 99% variance explained
n_components_for_99_variance = np.argmax(cumulative_variance_ratio >= 0.99) + 1

# Fit PCA with the number of components that explain 99% of variance
pca = PCA(n_components=n_components_for_99_variance)
pca.fit(featuresDF.iloc[:, 2:])  # Assuming first column is not a variable

# Transform the data to the new PCA space
features_pca = pca.transform(featuresDF.iloc[:, 2:])

# Add the PCA features to the dataframe	
featuresDF.reset_index(drop=True, inplace=True)
featuresDF = pd.concat([featuresDF['txId'], featuresDF['class'], pd.DataFrame(features_pca)], axis=1)

featuresDF.head(5)
# Out:
#         txId  class          0         1         2         3         4  \
# 0  232438397      0  23.864852 -2.872764  3.228163  2.249695 -1.673169
# 1  232029206      0  23.824778 -2.934407  1.707827  1.645776 -0.883985
# 2  232344069      0  23.633288 -6.174596 -0.690294  1.300851  1.060377
# 3   27553029      0  23.614107 -6.379561 -0.733770  1.392027  1.070526
# 4    3881097      0  24.902260 -4.827894  6.551374 -1.332144 -7.913342
#
#           5         6          7  ...        55        56        57        58  \
# 0  6.546972  3.914637  -2.741003  ... -2.036240  1.181648 -2.067406 -0.539306
# 1  4.429209  2.012115  -1.375751  ... -1.219557  0.754059 -0.878271 -0.262666
# 2 -1.651673 -0.563527   0.682696  ... -0.180718  0.111702  0.006486  0.528184
# 3 -1.741219 -0.485547   0.634511  ...  0.714017 -0.529625 -0.820842  0.912830
# 4  9.592823  8.273521 -13.287323  ...  0.686828  1.769213 -0.503321  0.676196
#
#          59        60        61        62        63        64
# 0 -0.381646  0.062452  0.067377 -0.019860  0.277298 -0.865069
# 1 -0.168157 -0.175585 -0.048877  0.030379  0.100802 -0.566540
# 2 -1.143062 -0.288328  0.410343  0.357442 -1.570367 -0.079824
# 3 -1.856052 -0.060776  0.949893 -0.082216 -0.525510 -0.021061
# 4 -1.696925  0.103431  0.732956 -0.346972  0.759762 -1.124043
#
# [5 rows x 67 columns]

# %% [markdown]
# ---
#
# # Create the dataset class

# %%
import torch
from torch.utils.data import Dataset

# %%
class Data(Dataset):
    def __init__(self, data):
        self.data = data
        self.features = self.data.columns[2:]
        self.vectors = self.data[self.features]
        self.vectors = torch.tensor(self.data[self.features].values, dtype=torch.float32)

    def __len__(self):
        return len(self.vectors)

    def __getitem__(self, idx):
        return self.vectors[idx]

# %% [markdown]
# ### Load the data into the dataset class

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

licitSamples = featuresDF[featuresDF['class'] == 0]
illicitSamples = featuresDF[featuresDF['class'] == 1]

# Obtain the needed samples to balance the dataset
AE_data = licitSamples.sample(n=len(licitSamples) - len(illicitSamples), random_state=42)

# Normalize the data
scaler = StandardScaler()
scaler.fit(AE_data.iloc[:, 2:])
AE_data.iloc[:, 2:] = scaler.transform(AE_data.iloc[:, 2:])

# Store licitSamples in a csv file
AE_data.to_csv('../../../data/AEData.csv', index=False)

# %%
trainAE, valAE = train_test_split(AE_data, test_size=0.15, random_state=42)

train_dataset = Data(trainAE)
val_dataset = Data(valAE)

print(f'Train size: {len(train_dataset)}')
print(f'Validation size: {len(val_dataset)}')
# Out:
# Train size: 31852
# Validation size: 5622

# %% [markdown]
# ### Load the datasets into Dataloaders

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=2048, shuffle=True)

# %% [markdown]
# ---
#
# # Create the model class

# %%
import torch.nn as nn

# %%
# Create autoencoder for input vectors of size 65

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(65, 48),
            nn.LeakyReLU(),
            nn.Linear(48, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 16),
            nn.LeakyReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 48),
            nn.LeakyReLU(),
            nn.Linear(48, 65),
            nn.LeakyReLU() 
        )
    
    def forward(self, in_features):
        encoded_features = self.encoder(in_features)
        out = self.decoder(encoded_features)
        return out

# %% [markdown]
# ---
#
# # Create the train and validate functions

# %%
import matplotlib.pyplot as plt
# from tqdm import tqdm

# %% [markdown]
# ### Create train function

# %%
def train(model, criterion, optimizer, train_loader, device):
    model.to(device)
    model.train()
    train_loss = 0

    for batch_features in train_loader:
        batch_features = batch_features.view(-1, 65).to(device)

        optimizer.zero_grad()
        outputs = model(batch_features)
        loss = criterion(outputs, batch_features)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    return train_loss

# %% [markdown]
# ### Create validate function

# %%
def validate(model, criterion, val_loader, device):
    model.to(device)
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_features in val_loader:
            batch_features = batch_features.view(-1, 65).to(device)
            outputs = model(batch_features)
            loss = criterion(outputs, batch_features)
            val_loss += loss.item()*10
    return val_loss

# %% [markdown]
# ### Create function to do both

# %%
def train_and_val(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs, device='cuda', name='AE_loss'):
    losses = []
    for epoch in range(1, epochs+1):
        train_loss = train(model, criterion, optimizer, train_loader, device)
        val_loss = validate(model, criterion, val_loader, device)
        scheduler.step()
        if epoch%100==0:
            print(f'Epoch: {epoch}, Training Loss: {train_loss}, Validation Loss: {val_loss}\n')
            losses.append([train_loss, val_loss])
    # plot the evolving loss
    plt.figure(figsize=(12, 8))
    plt.plot([i[0] for i in losses], label='Training Loss')
    plt.plot([i[1] for i in losses], label='Validation Loss')
    plt.legend()
    plt.savefig('models/' + str(name) + '.png')
    plt.show()
    return losses

# %% [markdown]
# ---
#
# # Train small sample of model

# %%
model = Autoencoder()
criterion = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.05)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
losses = train_and_val(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs=10000, device=device, name='Autoencoder_secondRUN')

# Save the model
torch.save(model.state_dict(), 'models/Autoencoder_secondRUN.pth')
# Out:
# Epoch: 100, Training Loss: 3.4259384721517563, Validation Loss: 6.504660546779633
#
# Epoch: 200, Training Loss: 3.590225651860237, Validation Loss: 6.781229078769684
#
# Epoch: 300, Training Loss: 3.1558573246002197, Validation Loss: 5.995945036411285
#
# Epoch: 400, Training Loss: 3.07109235227108, Validation Loss: 5.780440121889114
#
# Epoch: 500, Training Loss: 2.978769302368164, Validation Loss: 5.6407999992370605
#
# Epoch: 600, Training Loss: 2.9060232043266296, Validation Loss: 5.485876351594925
#
# Epoch: 700, Training Loss: 3.1098468601703644, Validation Loss: 5.700507462024689
#
# Epoch: 800, Training Loss: 2.8390344083309174, Validation Loss: 5.391934663057327
#
# Epoch: 900, Training Loss: 3.149076923727989, Validation Loss: 5.956391543149948
#
# Epoch: 1000, Training Loss: 2.956084653735161, Validation Loss: 5.59231773018837
#
# Epoch: 1100, Training Loss: 2.8488383889198303, Validation Loss: 5.427149385213852
#
# Epoch: 1200, Training Loss: 2.8288441449403763, Validation Loss: 5.416395962238312
#
# Epoch: 1300, Training Loss: 2.815949633717537, Validation Loss: 5.35798192024231
#
# Epoch: 1400, Training Loss: 2.795621320605278, Validation Loss: 5.3309643268585205
#
# Epoch: 1500, Training Loss: 2.7786692678928375, Validation Loss: 5.299845784902573
#
# Epoch: 1600, Training Loss: 2.7640534788370132, Validation Loss: 5.303274393081665
#
# Epoch: 1700, Training Loss: 2.7553381621837616, Validation Loss: 5.277526527643204
#
# Epoch: 1800, Training Loss: 2.758974254131317, Validation Loss: 5.267828106880188
#
# Epoch: 1900, Training Loss: 2.738774538040161, Validation Loss: 5.246502161026001
#
# Epoch: 2000, Training Loss: 2.734458565711975, Validation Loss: 5.254591107368469
#
# Epoch: 2100, Training Loss: 2.7274521589279175, Validation Loss: 5.252540111541748
#
# Epoch: 2200, Training Loss: 2.728003203868866, Validation Loss: 5.214671641588211
#
# Epoch: 2300, Training Loss: 2.724675640463829, Validation Loss: 5.241929143667221
#
# Epoch: 2400, Training Loss: 2.723623111844063, Validation Loss: 5.258963257074356
#
# Epoch: 2500, Training Loss: 2.728467211127281, Validation Loss: 5.233460366725922
#
# Epoch: 2600, Training Loss: 2.7251277565956116, Validation Loss: 5.2127499878406525
#
# Epoch: 2700, Training Loss: 2.722158893942833, Validation Loss: 5.25354877114296
#
# Epoch: 2800, Training Loss: 2.727470725774765, Validation Loss: 5.233084708452225
#
# Epoch: 2900, Training Loss: 2.7246746569871902, Validation Loss: 5.241395980119705
#
# Epoch: 3000, Training Loss: 2.7223583310842514, Validation Loss: 5.244225561618805
#
# Epoch: 3100, Training Loss: 2.7187684923410416, Validation Loss: 5.2191901206970215
#
# Epoch: 3200, Training Loss: 2.7189875543117523, Validation Loss: 5.23682177066803
#
# Epoch: 3300, Training Loss: 2.723326802253723, Validation Loss: 5.247064232826233
#
# Epoch: 3400, Training Loss: 2.7225303053855896, Validation Loss: 5.2307939529418945
#
# Epoch: 3500, Training Loss: 2.7224072217941284, Validation Loss: 5.248554348945618
#
# Epoch: 3600, Training Loss: 2.718655616044998, Validation Loss: 5.234211981296539
#
# Epoch: 3700, Training Loss: 2.71811680495739, Validation Loss: 5.2417707443237305
#
# Epoch: 3800, Training Loss: 2.724035620689392, Validation Loss: 5.231887698173523
#
# Epoch: 3900, Training Loss: 2.719934329390526, Validation Loss: 5.2301134169101715
#
# Epoch: 4000, Training Loss: 2.721187323331833, Validation Loss: 5.254778265953064
#
# Epoch: 4100, Training Loss: 2.7226927876472473, Validation Loss: 5.254223644733429
#
# Epoch: 4200, Training Loss: 2.716395542025566, Validation Loss: 5.245936214923859
#
# Epoch: 4300, Training Loss: 2.7201268672943115, Validation Loss: 5.2429333329200745
#
# Epoch: 4400, Training Loss: 2.720697373151779, Validation Loss: 5.246595144271851
#
# Epoch: 4500, Training Loss: 2.7203646302223206, Validation Loss: 5.261746346950531
#
# Epoch: 4600, Training Loss: 2.724796772003174, Validation Loss: 5.229776501655579
#
# Epoch: 4700, Training Loss: 2.723936080932617, Validation Loss: 5.228539556264877
#
# Epoch: 4800, Training Loss: 2.7235698848962784, Validation Loss: 5.234380513429642
#
# Epoch: 4900, Training Loss: 2.722630590200424, Validation Loss: 5.227968245744705
#
# Epoch: 5000, Training Loss: 2.7242074608802795, Validation Loss: 5.250997245311737
#
# Epoch: 5100, Training Loss: 2.7189293205738068, Validation Loss: 5.233461111783981
#
# Epoch: 5200, Training Loss: 2.7183028906583786, Validation Loss: 5.255146026611328
#
# Epoch: 5300, Training Loss: 2.719249665737152, Validation Loss: 5.241473317146301
#
# Epoch: 5400, Training Loss: 2.723362073302269, Validation Loss: 5.225861221551895
#
# Epoch: 5500, Training Loss: 2.7181369960308075, Validation Loss: 5.2359119057655334
#
# Epoch: 5600, Training Loss: 2.720446214079857, Validation Loss: 5.235022753477097
#
# Epoch: 5700, Training Loss: 2.72148959338665, Validation Loss: 5.248477607965469
#
# Epoch: 5800, Training Loss: 2.723950520157814, Validation Loss: 5.242595374584198
#
# Epoch: 5900, Training Loss: 2.71974515914917, Validation Loss: 5.237230658531189
#
# Epoch: 6000, Training Loss: 2.7170767337083817, Validation Loss: 5.238548219203949
#
# Epoch: 6100, Training Loss: 2.7272259891033173, Validation Loss: 5.262915343046188
#
# Epoch: 6200, Training Loss: 2.721749097108841, Validation Loss: 5.247736424207687
#
# Epoch: 6300, Training Loss: 2.7231966704130173, Validation Loss: 5.238166004419327
#
# Epoch: 6400, Training Loss: 2.720091700553894, Validation Loss: 5.239121466875076
#
# Epoch: 6500, Training Loss: 2.722477152943611, Validation Loss: 5.2364590764045715
#
# Epoch: 6600, Training Loss: 2.7238725423812866, Validation Loss: 5.233926773071289
#
# Epoch: 6700, Training Loss: 2.719885140657425, Validation Loss: 5.248523056507111
#
# Epoch: 6800, Training Loss: 2.7247971296310425, Validation Loss: 5.236508101224899
#
# Epoch: 6900, Training Loss: 2.7209921181201935, Validation Loss: 5.2210235595703125
#
# Epoch: 7000, Training Loss: 2.722577825188637, Validation Loss: 5.239358097314835
#
# Epoch: 7100, Training Loss: 2.7185031920671463, Validation Loss: 5.239246189594269
#
# Epoch: 7200, Training Loss: 2.7171346992254257, Validation Loss: 5.252474099397659
#
# Epoch: 7300, Training Loss: 2.7192337661981583, Validation Loss: 5.239931792020798
#
# Epoch: 7400, Training Loss: 2.7233587205410004, Validation Loss: 5.2409727871418
#
# Epoch: 7500, Training Loss: 2.7239679992198944, Validation Loss: 5.241592973470688
#
# Epoch: 7600, Training Loss: 2.725194036960602, Validation Loss: 5.247422158718109
#
# Epoch: 7700, Training Loss: 2.721518561244011, Validation Loss: 5.254383236169815
#
# Epoch: 7800, Training Loss: 2.7160511165857315, Validation Loss: 5.235347151756287
#
# Epoch: 7900, Training Loss: 2.722779557108879, Validation Loss: 5.233832746744156
#
# Epoch: 8000, Training Loss: 2.7219381630420685, Validation Loss: 5.22963672876358
#
# Epoch: 8100, Training Loss: 2.7216594219207764, Validation Loss: 5.242359787225723
#
# Epoch: 8200, Training Loss: 2.7233050167560577, Validation Loss: 5.23838073015213
#
# Epoch: 8300, Training Loss: 2.722095340490341, Validation Loss: 5.244795083999634
#
# Epoch: 8400, Training Loss: 2.7224162369966507, Validation Loss: 5.250433832406998
#
# Epoch: 8500, Training Loss: 2.7227393984794617, Validation Loss: 5.235632061958313
#
# Epoch: 8600, Training Loss: 2.7295115888118744, Validation Loss: 5.249288231134415
#
# Epoch: 8700, Training Loss: 2.7204947769641876, Validation Loss: 5.245998948812485
#
# Epoch: 8800, Training Loss: 2.7238615304231644, Validation Loss: 5.2387624979019165
#
# Epoch: 8900, Training Loss: 2.724908158183098, Validation Loss: 5.259279012680054
#
# Epoch: 9000, Training Loss: 2.7239806205034256, Validation Loss: 5.24434968829155
#
# Epoch: 9100, Training Loss: 2.718823656439781, Validation Loss: 5.228890925645828
#
# Epoch: 9200, Training Loss: 2.721848353743553, Validation Loss: 5.262218117713928
#
# Epoch: 9300, Training Loss: 2.7182863354682922, Validation Loss: 5.255696475505829
#
# Epoch: 9400, Training Loss: 2.718291997909546, Validation Loss: 5.241934955120087
#
# Epoch: 9500, Training Loss: 2.724386751651764, Validation Loss: 5.2518230676651
#
# Epoch: 9600, Training Loss: 2.7233286648988724, Validation Loss: 5.227435827255249
#
# Epoch: 9700, Training Loss: 2.718114912509918, Validation Loss: 5.24450421333313
#
# Epoch: 9800, Training Loss: 2.724618822336197, Validation Loss: 5.23030012845993
#
# Epoch: 9900, Training Loss: 2.721079498529434, Validation Loss: 5.254924446344376
#
# Epoch: 10000, Training Loss: 2.7198013961315155, Validation Loss: 5.228601545095444
