# %% [markdown]
# ---
#
# # Load the data

# %%
import pandas as pd
import numpy as np

# %%
classesDF  = pd.read_csv('../../../data/elliptic_txs_classes.csv')

# Remove all nodes that have unknown class
classesDF = classesDF[classesDF['class'] != "unknown"]

# If class = 2, then map to 0, else map to 1
classesDF['class'] = classesDF['class'].map({'2': 0, '1': 1})

classesDF.head(5)
# Out:
#          txId  class
# 3   232438397      0
# 9   232029206      0
# 10  232344069      0
# 11   27553029      0
# 16    3881097      0

# %%
featuresDF = pd.read_csv('../../../data/elliptic_txs_features.csv')

# Change column names --> Column 1 is txId, Column 2 is timestep and the rest are unknown features
featuresDF.columns = ['txId', 'timestep'] + ['f' + str(i) for i in range(165)]

# Remove all edges that do not appear in classesDF
featuresDF = featuresDF[featuresDF['txId'].isin(classesDF['txId'])]

featuresDF.head(5)
# Out:
#          txId  timestep        f0        f1        f2         f3        f4  \
# 2   232438397         1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 8   232029206         1 -0.005027  0.578941 -0.091383   4.380281 -0.063725
# 9   232344069         1 -0.147852 -0.184668 -1.201369  -0.121970 -0.043875
# 10   27553029         1 -0.151357 -0.184668 -1.201369  -0.121970 -0.043875
# 15    3881097         1 -0.172306 -0.184668 -1.201369   0.028105 -0.043875
#
#           f5         f6        f7  ...      f155      f156      f157  \
# 2   9.782742  12.414558 -0.163645  ... -0.577099 -0.613614  0.241128
# 8   4.667146   0.851305 -0.163645  ... -0.577099 -0.613614  0.241128
# 9  -0.113002  -0.061584 -0.137933  ... -0.577099 -0.613614  0.241128
# 10 -0.113002  -0.061584 -0.141519  ... -0.539735 -0.582077 -0.979074
# 15 -0.029140   0.242712 -0.163640  ... -0.577099 -0.600999  0.241128
#
#         f158      f159      f160      f161      f162      f163      f164
# 2   0.241406  1.072793  0.085530 -0.131155  0.677799 -0.120613 -0.119792
# 8   0.241406  0.604120  0.008632 -0.131155  0.333211 -0.120613 -0.119792
# 9   0.241406  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 10 -0.978556  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 15  0.241406  0.018279 -0.068266 -0.084674 -0.054450 -1.760926 -1.760984
#
# [5 rows x 167 columns]

# %%
# Append the class to the featuresDF based on txID
featuresDF = featuresDF.merge(classesDF, on='txId')

# Move features 'class' to first column
cols = list(featuresDF.columns)
cols = cols[:1] + [cols[-1]] + cols[1:-1]
featuresDF = featuresDF[cols]

featuresDF.head(5)
# Out:
#         txId  class  timestep        f0        f1        f2         f3  \
# 0  232438397      0         1  0.163054  1.963790 -0.646376  12.409294
# 1  232029206      0         1 -0.005027  0.578941 -0.091383   4.380281
# 2  232344069      0         1 -0.147852 -0.184668 -1.201369  -0.121970
# 3   27553029      0         1 -0.151357 -0.184668 -1.201369  -0.121970
# 4    3881097      0         1 -0.172306 -0.184668 -1.201369   0.028105
#
#          f4        f5         f6  ...      f155      f156      f157      f158  \
# 0 -0.063725  9.782742  12.414558  ... -0.577099 -0.613614  0.241128  0.241406
# 1 -0.063725  4.667146   0.851305  ... -0.577099 -0.613614  0.241128  0.241406
# 2 -0.043875 -0.113002  -0.061584  ... -0.577099 -0.613614  0.241128  0.241406
# 3 -0.043875 -0.113002  -0.061584  ... -0.539735 -0.582077 -0.979074 -0.978556
# 4 -0.043875 -0.029140   0.242712  ... -0.577099 -0.600999  0.241128  0.241406
#
#        f159      f160      f161      f162      f163      f164
# 0  1.072793  0.085530 -0.131155  0.677799 -0.120613 -0.119792
# 1  0.604120  0.008632 -0.131155  0.333211 -0.120613 -0.119792
# 2  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 3  0.018279 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 4  0.018279 -0.068266 -0.084674 -0.054450 -1.760926 -1.760984
#
# [5 rows x 168 columns]

# %% [markdown]
# ### Compute PCA to reduce the dimensionality of the features

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Compute PCA on the features
pca = PCA()
pca.fit(featuresDF.iloc[:, 2:]) # Ignore the first column (txId)

# Calculate cumulative explained variance ratio
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Set a threshold of 99% variance explained
n_components_for_99_variance = np.argmax(cumulative_variance_ratio >= 0.99) + 1

# Fit PCA with the number of components that explain 99% of variance
pca = PCA(n_components=n_components_for_99_variance)
pca.fit(featuresDF.iloc[:, 2:])  # Assuming first column is not a variable

# Transform the data to the new PCA space
features_pca = pca.transform(featuresDF.iloc[:, 2:])

# Add the PCA features to the dataframe	
featuresDF.reset_index(drop=True, inplace=True)
featuresDF = pd.concat([featuresDF['txId'], featuresDF['class'], pd.DataFrame(features_pca)], axis=1)

featuresDF.head(5)
# Out:
#         txId  class          0         1         2         3         4  \
# 0  232438397      0  23.864852 -2.872764  3.228163  2.249695 -1.673169
# 1  232029206      0  23.824778 -2.934407  1.707827  1.645776 -0.883985
# 2  232344069      0  23.633288 -6.174596 -0.690294  1.300851  1.060377
# 3   27553029      0  23.614107 -6.379561 -0.733770  1.392027  1.070526
# 4    3881097      0  24.902260 -4.827894  6.551374 -1.332144 -7.913342
#
#           5         6          7  ...        55        56        57        58  \
# 0  6.546972  3.914637  -2.741003  ... -2.034221  1.182310 -2.068133 -0.539092
# 1  4.429209  2.012115  -1.375751  ... -1.219493  0.754089 -0.878487 -0.262545
# 2 -1.651673 -0.563527   0.682696  ... -0.180718  0.111716  0.006475  0.528161
# 3 -1.741219 -0.485547   0.634511  ...  0.714017 -0.529618 -0.820834  0.912794
# 4  9.592823  8.273521 -13.287323  ...  0.687105  1.769307 -0.503290  0.676078
#
#          59        60        61        62        63        64
# 0 -0.380883  0.065940  0.076955 -0.045756  0.301670 -0.841111
# 1 -0.168044 -0.175156 -0.049037  0.030284  0.102329 -0.566063
# 2 -1.143070 -0.288322  0.409007  0.360478 -1.570007 -0.078986
# 3 -1.856075 -0.060690  0.949773 -0.079275 -0.525962 -0.020368
# 4 -1.696936  0.104126  0.734606 -0.348520  0.760869 -1.122055
#
# [5 rows x 67 columns]

# %% [markdown]
# ---
#
# # Create the dataset class

# %%
import torch
from torch.utils.data import Dataset

# %%
class Data(Dataset):
    def __init__(self, data):
        self.data = data
        self.features = self.data.columns[2:]
        self.vectors = self.data[self.features]
        self.vectors = torch.tensor(self.data[self.features].values, dtype=torch.float32)

    def __len__(self):
        return len(self.vectors)

    def __getitem__(self, idx):
        return self.vectors[idx]

# %% [markdown]
# ### Load the data into the dataset class

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

licitSamples = featuresDF[featuresDF['class'] == 0]
illicitSamples = featuresDF[featuresDF['class'] == 1]

# Obtain the needed samples to balance the dataset
AE_data = licitSamples.sample(n=len(licitSamples) - len(illicitSamples), random_state=42)

# Normalize the data
scaler = StandardScaler()
scaler.fit(AE_data.iloc[:, 2:])
AE_data.iloc[:, 2:] = scaler.transform(AE_data.iloc[:, 2:])

# Store licitSamples in a csv file
AE_data.to_csv('../../../data/AEData.csv', index=False)

# %%
trainAE, valAE = train_test_split(AE_data, test_size=0.15, random_state=42)

train_dataset = Data(trainAE)
val_dataset = Data(valAE)

print(f'Train size: {len(train_dataset)}')
print(f'Validation size: {len(val_dataset)}')
# Out:
# Train size: 31852
# Validation size: 5622

# %% [markdown]
# ### Load the datasets into Dataloaders

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=2048, shuffle=True)

# %% [markdown]
# ---
#
# # Create the model class

# %%
import torch.nn as nn

# %%
# Create autoencoder for input vectors of size 166

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(65, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 16),
            nn.LeakyReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 65),
            nn.LeakyReLU()  # Output between 0 and 1
        )
    
    def forward(self, in_features):
        encoded_features = self.encoder(in_features)
        out = self.decoder(encoded_features)
        return out

# %% [markdown]
# ---
#
# # Create the train and validate functions

# %%
import matplotlib.pyplot as plt
# from tqdm import tqdm

# %% [markdown]
# ### Create train function

# %%
def train(model, criterion, optimizer, train_loader, device):
    model.to(device)
    model.train()
    train_loss = 0

    for batch_features in train_loader:
        batch_features = batch_features.view(-1, 65).to(device)

        optimizer.zero_grad()
        outputs = model(batch_features)
        loss = criterion(outputs, batch_features)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    return train_loss

# %% [markdown]
# ### Create validate function

# %%
def validate(model, criterion, val_loader, device):
    model.to(device)
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch_features in val_loader:
            batch_features = batch_features.view(-1, 65).to(device)
            outputs = model(batch_features)
            loss = criterion(outputs, batch_features)
            val_loss += loss.item()*10
    return val_loss

# %% [markdown]
# ### Create function to do both

# %%
def train_and_val(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs, device='cuda'):
    history = []
    for epoch in range(1, epochs+1):
        train_loss = train(model, criterion, optimizer, train_loader, device)
        val_loss = validate(model, criterion, val_loader, device)
        scheduler.step()
        if epoch%100==0:
            print(f'Epoch: {epoch}, Training Loss: {train_loss}, Validation Loss: {val_loss}\n')
            history.append([train_loss, val_loss])
    # plot the evolving loss
    plt.figure(figsize=(12, 8))
    plt.plot([i[0] for i in history], label='Training Loss')
    plt.plot([i[1] for i in history], label='Validation Loss')
    plt.legend()
    plt.savefig('models/AE_loss_firstRUN.png')
    plt.show()
    return history

# %% [markdown]
# ---
#
# # Train small sample of model

# %%
model = Autoencoder()
criterion = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.03)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.05)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
history = train_and_val(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs=10000, device=device)

# Save the model
torch.save(model.state_dict(), 'models/Autoencoder_firstRUN.pth')
# Out:
# Epoch: 100, Training Loss: 3.425219640135765, Validation Loss: 6.428727358579636
#
# Epoch: 200, Training Loss: 3.3252710103988647, Validation Loss: 6.264889985322952
#
# Epoch: 300, Training Loss: 3.3173423558473587, Validation Loss: 6.220974922180176
#
# Epoch: 400, Training Loss: 3.2964562326669693, Validation Loss: 6.195757240056992
#
# Epoch: 500, Training Loss: 3.2308389544487, Validation Loss: 6.092132776975632
#
# Epoch: 600, Training Loss: 3.2561428248882294, Validation Loss: 6.153551787137985
#
# Epoch: 700, Training Loss: 3.238123655319214, Validation Loss: 6.078225821256638
#
# Epoch: 800, Training Loss: 3.232430085539818, Validation Loss: 6.1617112159729
#
# Epoch: 900, Training Loss: 3.200339287519455, Validation Loss: 6.008037775754929
#
# Epoch: 1000, Training Loss: 3.2186389714479446, Validation Loss: 6.020021140575409
#
# Epoch: 1100, Training Loss: 3.078230693936348, Validation Loss: 5.813341736793518
#
# Epoch: 1200, Training Loss: 3.0701645463705063, Validation Loss: 5.806497782468796
#
# Epoch: 1300, Training Loss: 3.0675260573625565, Validation Loss: 5.821995884180069
#
# Epoch: 1400, Training Loss: 3.0600196570158005, Validation Loss: 5.822980105876923
#
# Epoch: 1500, Training Loss: 3.050106629729271, Validation Loss: 5.807380527257919
#
# Epoch: 1600, Training Loss: 3.0506889075040817, Validation Loss: 5.8049993216991425
#
# Epoch: 1700, Training Loss: 3.042031094431877, Validation Loss: 5.798905193805695
#
# Epoch: 1800, Training Loss: 3.040769651532173, Validation Loss: 5.7798270881175995
#
# Epoch: 1900, Training Loss: 3.0419607013463974, Validation Loss: 5.789727568626404
#
# Epoch: 2000, Training Loss: 3.033351391553879, Validation Loss: 5.804155617952347
#
# Epoch: 2100, Training Loss: 3.0346724689006805, Validation Loss: 5.802987366914749
#
# Epoch: 2200, Training Loss: 3.028931975364685, Validation Loss: 5.807453542947769
#
# Epoch: 2300, Training Loss: 3.0287052989006042, Validation Loss: 5.797603875398636
#
# Epoch: 2400, Training Loss: 3.035926789045334, Validation Loss: 5.789146274328232
#
# Epoch: 2500, Training Loss: 3.036352202296257, Validation Loss: 5.807694345712662
#
# Epoch: 2600, Training Loss: 3.0329733788967133, Validation Loss: 5.803679525852203
#
# Epoch: 2700, Training Loss: 3.0349273085594177, Validation Loss: 5.780765414237976
#
# Epoch: 2800, Training Loss: 3.031095191836357, Validation Loss: 5.794386565685272
#
# Epoch: 2900, Training Loss: 3.0315456986427307, Validation Loss: 5.818555504083633
#
# Epoch: 3000, Training Loss: 3.0328472554683685, Validation Loss: 5.784225612878799
#
# Epoch: 3100, Training Loss: 3.0360146164894104, Validation Loss: 5.790846794843674
#
# Epoch: 3200, Training Loss: 3.03020241856575, Validation Loss: 5.811703652143478
#
# Epoch: 3300, Training Loss: 3.0290473997592926, Validation Loss: 5.7955919206142426
#
# Epoch: 3400, Training Loss: 3.0385473668575287, Validation Loss: 5.7703350484371185
#
# Epoch: 3500, Training Loss: 3.030486300587654, Validation Loss: 5.80757662653923
#
# Epoch: 3600, Training Loss: 3.030125007033348, Validation Loss: 5.776195079088211
#
# Epoch: 3700, Training Loss: 3.029271587729454, Validation Loss: 5.803084969520569
#
# Epoch: 3800, Training Loss: 3.0332902520895004, Validation Loss: 5.803700089454651
#
# Epoch: 3900, Training Loss: 3.0331201404333115, Validation Loss: 5.795217901468277
#
# Epoch: 4000, Training Loss: 3.033517509698868, Validation Loss: 5.790449678897858
#
# Epoch: 4100, Training Loss: 3.0364906191825867, Validation Loss: 5.778643190860748
#
# Epoch: 4200, Training Loss: 3.032091900706291, Validation Loss: 5.792764872312546
#
# Epoch: 4300, Training Loss: 3.025737851858139, Validation Loss: 5.806928128004074
#
# Epoch: 4400, Training Loss: 3.0394017845392227, Validation Loss: 5.798375308513641
#
# Epoch: 4500, Training Loss: 3.0298203378915787, Validation Loss: 5.799793601036072
#
# Epoch: 4600, Training Loss: 3.0313831716775894, Validation Loss: 5.7961405813694
#
# Epoch: 4700, Training Loss: 3.0393038988113403, Validation Loss: 5.795142948627472
#
# Epoch: 4800, Training Loss: 3.0327942818403244, Validation Loss: 5.80170750617981
#
# Epoch: 4900, Training Loss: 3.035706952214241, Validation Loss: 5.784920156002045
#
# Epoch: 5000, Training Loss: 3.0315301418304443, Validation Loss: 5.792380273342133
#
# Epoch: 5100, Training Loss: 3.0276742577552795, Validation Loss: 5.81379622220993
#
# Epoch: 5200, Training Loss: 3.0274756103754044, Validation Loss: 5.783918052911758
#
# Epoch: 5300, Training Loss: 3.0329910218715668, Validation Loss: 5.806326866149902
#
# Epoch: 5400, Training Loss: 3.033963993191719, Validation Loss: 5.792548209428787
#
# Epoch: 5500, Training Loss: 3.0350907146930695, Validation Loss: 5.793739557266235
#
# Epoch: 5600, Training Loss: 3.0289213061332703, Validation Loss: 5.793693661689758
#
# Epoch: 5700, Training Loss: 3.031395986676216, Validation Loss: 5.803684890270233
#
# Epoch: 5800, Training Loss: 3.0311128050088882, Validation Loss: 5.827730745077133
#
# Epoch: 5900, Training Loss: 3.0316700488328934, Validation Loss: 5.790729224681854
#
# Epoch: 6000, Training Loss: 3.032333165407181, Validation Loss: 5.779688656330109
#
# Epoch: 6100, Training Loss: 3.0282939672470093, Validation Loss: 5.7733698189258575
#
# Epoch: 6200, Training Loss: 3.029948130249977, Validation Loss: 5.779417902231216
#
# Epoch: 6300, Training Loss: 3.027582958340645, Validation Loss: 5.807067006826401
#
# Epoch: 6400, Training Loss: 3.0381069481372833, Validation Loss: 5.803957879543304
#
# Epoch: 6500, Training Loss: 3.033136337995529, Validation Loss: 5.806466788053513
#
# Epoch: 6600, Training Loss: 3.0301052182912827, Validation Loss: 5.783490091562271
#
# Epoch: 6700, Training Loss: 3.03166101872921, Validation Loss: 5.783647447824478
#
# Epoch: 6800, Training Loss: 3.0300322622060776, Validation Loss: 5.778225213289261
#
# Epoch: 6900, Training Loss: 3.0308644771575928, Validation Loss: 5.807190984487534
#
# Epoch: 7000, Training Loss: 3.0288903564214706, Validation Loss: 5.801592618227005
#
# Epoch: 7100, Training Loss: 3.033950164914131, Validation Loss: 5.798742473125458
#
# Epoch: 7200, Training Loss: 3.029191330075264, Validation Loss: 5.775801837444305
#
# Epoch: 7300, Training Loss: 3.0306397825479507, Validation Loss: 5.780571848154068
#
# Epoch: 7400, Training Loss: 3.0370780378580093, Validation Loss: 5.778026431798935
#
# Epoch: 7500, Training Loss: 3.02834652364254, Validation Loss: 5.798706263303757
#
# Epoch: 7600, Training Loss: 3.0350469201803207, Validation Loss: 5.792607069015503
#
# Epoch: 7700, Training Loss: 3.033997565507889, Validation Loss: 5.774420350790024
#
# Epoch: 7800, Training Loss: 3.034574255347252, Validation Loss: 5.777166783809662
#
# Epoch: 7900, Training Loss: 3.0308271050453186, Validation Loss: 5.798253118991852
#
# Epoch: 8000, Training Loss: 3.034243255853653, Validation Loss: 5.776043087244034
#
# Epoch: 8100, Training Loss: 3.0345766991376877, Validation Loss: 5.797963738441467
#
# Epoch: 8200, Training Loss: 3.030730664730072, Validation Loss: 5.780801922082901
#
# Epoch: 8300, Training Loss: 3.026975467801094, Validation Loss: 5.828002095222473
#
# Epoch: 8400, Training Loss: 3.0329543203115463, Validation Loss: 5.756213366985321
#
# Epoch: 8500, Training Loss: 3.0309894531965256, Validation Loss: 5.781009644269943
#
# Epoch: 8600, Training Loss: 3.0314320623874664, Validation Loss: 5.801800340414047
#
# Epoch: 8700, Training Loss: 3.0291835963726044, Validation Loss: 5.792142748832703
#
# Epoch: 8800, Training Loss: 3.030098184943199, Validation Loss: 5.790131688117981
#
# Epoch: 8900, Training Loss: 3.0271747410297394, Validation Loss: 5.7882359623909
#
# Epoch: 9000, Training Loss: 3.028034806251526, Validation Loss: 5.778002589941025
#
# Epoch: 9100, Training Loss: 3.028015449643135, Validation Loss: 5.810682326555252
#
# Epoch: 9200, Training Loss: 3.02833154797554, Validation Loss: 5.772683620452881
#
# Epoch: 9300, Training Loss: 3.0263718217611313, Validation Loss: 5.7899631559848785
#
# Epoch: 9400, Training Loss: 3.0273710638284683, Validation Loss: 5.821613818407059
#
# Epoch: 9500, Training Loss: 3.0313723385334015, Validation Loss: 5.792671740055084
#
# Epoch: 9600, Training Loss: 3.03415247797966, Validation Loss: 5.797174274921417
#
# Epoch: 9700, Training Loss: 3.0335263907909393, Validation Loss: 5.803203582763672
#
# Epoch: 9800, Training Loss: 3.0324340164661407, Validation Loss: 5.810254365205765
#
# Epoch: 9900, Training Loss: 3.031858801841736, Validation Loss: 5.799472481012344
#
# Epoch: 10000, Training Loss: 3.0361428558826447, Validation Loss: 5.794763267040253
